# %%
import cv2
import mediapipe as mp
import json
import os
import numpy as np

# Input and output directories
input_dir = "./resistive_band_person_16/"
# input_dir = "./my_resistive_test/"    # another tests
output_dir = "./output/"
keypoints_dir = "./keypoints/"

# Create output directories if they don't exist
os.makedirs(output_dir, exist_ok=True)
os.makedirs(keypoints_dir, exist_ok=True)

# Initialize MediaPipe Pose and Face Detection
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_face_detection = mp.solutions.face_detection

# Define function to blur a keypoint
def blur_keypoint(image, x, y, radius=30):
    h, w, _ = image.shape
    cx, cy = int(x * w), int(y * h)  # Convert normalized coordinates to pixel positions
    
    if 0 <= cx < w and 0 <= cy < h:
        # Define the region of interest (ROI) around the keypoint with a square area (using the radius)
        top_left_x = max(0, cx - radius)
        top_left_y = max(0, cy - radius)
        bottom_right_x = min(w, cx + radius)
        bottom_right_y = min(h, cy + radius)
        
        # Extract the region of interest (ROI) around the keypoint
        roi = image[top_left_y:bottom_right_y, top_left_x:bottom_right_x]
        
        # Apply Gaussian blur to the ROI
        blurred_roi = cv2.GaussianBlur(roi, (0, 0), sigmaX=radius, sigmaY=radius)
        
        # Place the blurred ROI back into the image
        image[top_left_y:bottom_right_y, top_left_x:bottom_right_x] = blurred_roi


# Process all images in the input directory
with mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5) as pose:
    for filename in os.listdir(input_dir):
        face_detection = mp_face_detection.FaceDetection(min_detection_confidence=0.2)
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            # Load the image
            image_path = os.path.join(input_dir, filename)
            image = cv2.imread(image_path)
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Process the image to extract pose
            results = pose.process(image_rgb)
            face_results = face_detection.process(image_rgb)

            if results.pose_landmarks:
                # Blur head keypoints (e.g., Nose, Left Eye, Right Eye, Left Ear, Right Ear)
                head_keypoints = [
                    mp_pose.PoseLandmark.NOSE,
                    # mp_pose.PoseLandmark.LEFT_EYE,
                    # mp_pose.PoseLandmark.RIGHT_EYE,
                    # mp_pose.PoseLandmark.LEFT_EAR,
                    # mp_pose.PoseLandmark.RIGHT_EAR,
                    # mp_pose.PoseLandmark.MOUTH_LEFT,
                    # mp_pose.PoseLandmark.MOUTH_RIGHT
                ]
                for keypoint in head_keypoints:
                    kp = results.pose_landmarks.landmark[keypoint]
                    blur_keypoint(image, kp.x, kp.y)

                # Draw the skeleton on the image
                annotated_image = image.copy()
                mp_drawing.draw_landmarks(
                    annotated_image,
                    results.pose_landmarks,
                    mp_pose.POSE_CONNECTIONS,
                    landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style()
                )

                # Save the annotated image
                output_path = os.path.join(output_dir, filename)
                cv2.imwrite(output_path, annotated_image)

                # Save keypoints to JSON
                keypoints = {}
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    keypoints[idx] = {
                        "x": landmark.x,
                        "y": landmark.y,
                        "z": landmark.z,
                        "visibility": landmark.visibility
                    }

                keypoints_path = os.path.join(keypoints_dir, f"{os.path.splitext(filename)[0]}.json")
                with open(keypoints_path, "w") as json_file:
                    json.dump(keypoints, json_file, indent=4)
# Out:
# I0000 00:00:1736183641.593035   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183641.597630   37848 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# I0000 00:00:1736183641.601734   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183641.606403   37861 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183641.612468   37852 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736183641.656200   37840 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736183641.676920   37845 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183641.709460   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183641.710942   37871 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183641.713151   37864 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183641.751998   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183641.753353   37881 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183641.755821   37875 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183641.797901   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183641.799393   37891 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183641.802513   37884 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183641.847399   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183641.848833   37901 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183641.851350   37895 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183641.898662   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183641.900912   37912 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183641.902501   37905 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183641.949166   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183641.950781   37922 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183641.953221   37916 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183641.993630   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183641.994980   37932 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183641.997310   37924 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.036586   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.038074   37942 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.040426   37934 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.081370   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.083158   37952 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.085565   37944 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.125581   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.126949   37962 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.128353   37955 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.169610   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.171544   37972 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.173476   37964 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.213365   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.215096   37982 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.217211   37976 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.257622   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.259251   37992 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.261462   37985 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.304286   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.305764   38002 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.308756   37997 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.348573   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.350023   38012 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.352245   38007 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.393739   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.395139   38022 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.397639   38015 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.437489   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.439008   38032 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.441212   38025 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.480789   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.482338   38042 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.484073   38036 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.524366   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.525930   38052 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.528248   38045 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.568211   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.569548   38062 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.571865   38056 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.611135   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.612560   38072 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.614940   38067 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.653958   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.655482   38082 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.657752   38077 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.697932   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.699301   38092 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.702424   38086 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.741239   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.742939   38102 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.745716   38094 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.786355   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.787863   38112 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.789897   38106 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.833126   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.834514   38122 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.836725   38113 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.877140   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.878491   38132 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.880861   38126 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.922013   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.923487   38142 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.925784   38135 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183642.969129   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183642.970760   38152 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183642.972927   38145 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.014621   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.015905   38162 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.018152   38153 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.063216   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.064642   38173 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.067323   38165 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.114724   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.116695   38184 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.119004   38178 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.161276   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.162669   38194 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.164877   38185 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.205375   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.206989   38204 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.209892   38199 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.252030   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.253663   38214 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.256338   38205 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.295950   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.297359   38224 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.299842   38217 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.347260   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.348741   38241 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.350451   38234 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.392741   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.394281   38251 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.396772   38244 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.439079   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.440487   38261 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.443216   38253 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.484196   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.485743   38271 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.488014   38265 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.528639   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.530005   38281 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.532315   38275 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.572053   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.573530   38291 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.575030   38284 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.616305   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.617804   38301 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.620132   38295 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.661540   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.663458   38311 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.665504   38305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.704955   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.706702   38321 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.709447   38315 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.751063   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.752461   38331 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.754864   38324 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.799063   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.800510   38381 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.802908   38373 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.843972   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.845584   38391 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.847940   38384 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.888211   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.889726   38401 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.892079   38395 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.936705   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.938239   38411 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.939468   38405 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183643.983714   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183643.985177   38421 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183643.987607   38416 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.029699   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.031248   38431 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.034213   38424 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.081648   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.083462   38441 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.086167   38434 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.132992   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.134860   38451 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.138248   38445 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.179831   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.181227   38461 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.183816   38454 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.225545   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.227086   38471 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.229232   38464 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.276513   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.277947   38481 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.280799   38474 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.324493   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.326175   38491 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.328602   38484 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.371181   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.372552   38501 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.375095   38494 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.417022   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.418616   38511 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.420828   38504 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.462433   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.464145   38521 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.466415   38513 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.510539   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.512014   38531 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.513518   38524 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.555618   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.556970   38541 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.559634   38535 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.601616   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.603050   38551 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.605190   38543 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.646018   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.647562   38561 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.650430   38554 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.690380   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.691872   38571 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.694345   38565 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.733891   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.735291   38581 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.738128   38574 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.784222   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.785672   38591 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.788057   38584 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.839669   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.841177   38601 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.843023   38594 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.888143   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.890385   38611 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.893450   38604 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.936885   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.938353   38621 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.940745   38612 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183644.985865   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183644.987784   38631 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183644.990172   38623 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.043272   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.044943   38641 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.047338   38632 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.098040   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.100340   38651 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.102476   38644 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.167562   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.169440   38661 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.171092   38652 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.225668   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.227458   38671 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.229384   38664 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.279517   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.281083   38681 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.284141   38673 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.326307   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.327741   38691 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.330833   38684 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.371846   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.373367   38710 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.376496   38704 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.418034   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.419543   38720 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.421744   38714 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.462783   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.464135   38730 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.466486   38723 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.506534   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.508195   38740 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.509949   38734 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.550864   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.552609   38750 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.554798   38745 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.595666   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.597084   38760 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.599962   38754 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.637804   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.639395   38770 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.641792   38763 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.681678   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.683319   38780 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.685453   38773 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.728155   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.729597   38790 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.732444   38784 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.771692   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.773136   38800 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.775670   38795 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.816775   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.818713   38810 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.820788   38802 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.869212   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.872648   38820 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.877127   38811 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183645.935324   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183645.937314   38830 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183645.941587   38824 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.008140   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.010053   38840 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.013936   38837 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.066301   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.067923   38850 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.070743   38843 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.129274   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.130990   38860 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.133950   38854 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.178847   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.180555   38870 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.182977   38864 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.221632   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.223224   38880 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.225805   38872 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.269724   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.271322   38890 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.274516   38883 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.315540   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.317008   38900 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.319396   38894 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.360535   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.362004   38910 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.364247   38902 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.405225   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.406809   38923 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.409958   38917 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.449950   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.451652   38933 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.453326   38926 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.493820   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.495370   38943 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.497649   38937 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.536841   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.538713   38953 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.541273   38948 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.581954   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.583444   38963 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.585621   38957 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.625277   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.626823   38973 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.629566   38965 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.670250   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183646.671904   38983 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183646.673149   38976 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183646.714164   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# ...
# I0000 00:00:1736183648.638040   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183648.639586   39413 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183648.642065   39405 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183648.682154   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183648.683726   39423 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183648.685997   39419 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183648.726361   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183648.727980   39433 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183648.731297   39427 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183648.774539   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183648.776197   39443 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183648.778587   39437 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183648.819781   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183648.821201   39453 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183648.823352   39445 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183648.863730   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183648.865152   39463 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183648.867517   39457 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183648.906703   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183648.908211   39473 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183648.910799   39465 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183648.951107   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183648.952537   39483 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183648.954696   39475 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.006020   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.007935   39493 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.010595   39487 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.054567   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.056545   39503 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.059365   39496 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.105867   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.107675   39513 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.110450   39506 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.154151   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.155605   39523 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.157993   39517 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.200015   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.201442   39533 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.203787   39527 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.244551   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.246132   39543 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.249131   39536 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.290364   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.292167   39553 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.294976   39547 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.338179   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.339609   39563 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.342423   39555 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.385542   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.387097   39573 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.388354   39567 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.430870   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.432321   39583 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.434773   39577 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.477264   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.478922   39593 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.481278   39586 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.523768   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.525417   39603 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.527985   39596 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.570403   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.571812   39613 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.574439   39607 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.614032   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.615562   39623 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.616716   39616 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.660427   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.662461   39633 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.665409   39626 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.703280   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.704970   39643 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.707023   39636 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.747495   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.748935   39653 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.751724   39649 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.796130   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.798047   39663 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.801241   39656 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.861105   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.863279   39673 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.867703   39666 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.914147   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.915718   39683 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.918266   39674 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183649.965752   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183649.967341   39693 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183649.972282   39687 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183650.044233   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183650.046776   39703 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183650.048673   39695 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183650.099145   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183650.101000   39713 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183650.103434   39706 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183650.152957   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183650.154676   39723 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183650.157595   39715 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183650.205356   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183650.207187   39733 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183650.209896   39727 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183650.252021   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183650.253581   39743 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183650.256183   39737 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183650.300304   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183650.302231   39753 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183650.304875   39746 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736183650.350969   33601 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736183650.352453   39763 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1), renderer: Mesa Intel(R) Xe Graphics (TGL GT2)
# W0000 00:00:1736183650.355691   39756 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
